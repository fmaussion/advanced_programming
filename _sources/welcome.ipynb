# %% [markdown]
# # Welcome

# %% [markdown]
# ```{figure} img/logo_acinn_small.jpg
# ---
# figclass: margin
# ---
# ```
#
# Lecture notes of the bachelor lecture [Advanced Scientific Programming](https://lfuonline.uibk.ac.at/public/lfuonline_lv.details?sem_id_in=22S&lvnr_id_in=707833), taught as an optional advanced course for to students following a [Master in Atmospheric and Cryospheric Sciences](https://www.uibk.ac.at/acinn/studies/master-in-atmospheric-sciences.html.en) curriculum at the University of Innsbruck.
#
# This lecture is tailored for a 15 weeks-long class, but these notes might also be of interest to other (geo-)scientists wanting to learn more advanced scientific programming skills. **Welcome to you all!**
#
#
# ![](img/welcome_img.jpg)

# %% [markdown]
# ## Authors

# %% [markdown]
# - [Fabien Maussion](http://fabienmaussion.info/) wrote these notes (unless specified otherwise, e.g. for some tutorials)
